# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error
from sklearn.preprocessing import MinMaxScaler

# Load the data
merged_downtown_data = pd.read_csv('./merged_downtown_data.csv')
ridesourcing_data = pd.read_csv("./Ridesourcing_CensusCount_ALL_0_Filled.csv")

# Renaming and setting index for merging
merged_downtown_data = merged_downtown_data.rename(columns={"TractID": "index"})
merged_downtown_data.set_index("index", inplace=True)
ridesourcing_data.set_index("index", inplace=True)

# Merging the dataframes
merged_df = merged_downtown_data.join(ridesourcing_data, how='inner')

# Dropping the unnecessary columns
columns_to_drop = ["Unnamed: 0", "X", "Y"]
merged_df = merged_df.drop(columns=columns_to_drop)

# Create the "is_downtown" column
downtown_areas = [
    '17031839000', '17031080202', '17031833000', '17031833100', '17031839100', 
    '17031081201', '17031080201', '17031081202', '17031842200', '17031838300', 
    '17031081401', '17031081403', '17031081300', '17031081100', '17031080300', 
    '17031080100', '17031080400', '17031081000', '17031320400', '17031320600', 
    '17031081402', '17031320100', '17031081900', '17031081500', '17031081800', 
    '17031081600', '17031081700', '17031280100', '17031281900'
]

downtown_areas = [int(tract_id) for tract_id in downtown_areas]
merged_df['is_downtown'] = merged_df.index.isin(downtown_areas).astype(int)

# Verify the 'is_downtown' column
print("Is Downtown Column Distribution:\n", merged_df['is_downtown'].value_counts())

# Aggregate the travel demand by summing across all time columns
ridesourcing_data_aggregated = ridesourcing_data.sum(axis=1)

# Splitting the data into features and aggregated target
features = merged_df.drop(columns=ridesourcing_data.columns)
target = ridesourcing_data_aggregated

# Create MinMaxScaler instances for features and target
feature_scaler = MinMaxScaler()
target_scaler = MinMaxScaler()

# Fit and transform the features and target
features_scaled = feature_scaler.fit_transform(features)
target_scaled = target_scaler.fit_transform(target.values.reshape(-1, 1)).flatten()

# Use stratified sampling to split the data
train_indices, test_indices = train_test_split(range(len(features_scaled)), test_size=0.2, stratify=merged_df['is_downtown'])
X_train, X_test = features_scaled[train_indices], features_scaled[test_indices]
y_train, y_test = target_scaled[train_indices], target_scaled[test_indices]
is_downtown_train = merged_df['is_downtown'].iloc[train_indices].to_numpy().astype(float)
is_downtown_test = merged_df['is_downtown'].iloc[test_indices].to_numpy().astype(float)

# Define the PyTorch dataset and dataloader
class TravelDataset(Dataset):
    def __init__(self, X, y, is_downtown):
        self.X = X
        self.y = y
        self.is_downtown = is_downtown

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        x = self.X[idx, :].astype(np.float32)
        y = np.array(self.y[idx], dtype=np.float32)
        is_downtown = np.array(self.is_downtown[idx], dtype=np.float32)
        return torch.from_numpy(x).unsqueeze(0), torch.from_numpy(y), torch.from_numpy(is_downtown)

train_dataset = TravelDataset(X_train, y_train, is_downtown_train)
test_dataset = TravelDataset(X_test, y_test, is_downtown_test)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# Define the Net model
class Net(nn.Module):
    def __init__(self, n_features, n_neurons, device, seq_len, pre_len):
        super(Net, self).__init__()
        self.flatten = nn.Flatten()
        self.device = device
        self.n_features = n_features
        self.n_neurons = n_neurons
        self.seq_len = seq_len
        self.pre_len = pre_len
        
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(n_features, n_neurons),
            #nn.Tanh(),
            nn.Dropout(p = 0.01),
            nn.Linear(n_neurons, pre_len),
            #nn.Tanh(),
            nn.Dropout(p = 0.01),
        )

    def forward(self, x):
        pred = self.linear_relu_stack(x).to(self.device)
        return pred.squeeze()

def combined_loss(outputs, targets, is_downtown, lam=0.5):
    mse_loss = nn.MSELoss()(outputs, targets)
    monotonicity_penalty = 0.0
    violation_count = 0

    for i in range(len(outputs)):
        for j in range(len(outputs)):
            if is_downtown[i] > is_downtown[j] and outputs[i] < outputs[j]:
                monotonicity_penalty += outputs[j] - outputs[i]
                violation_count += 1

    cost = mse_loss + lam * monotonicity_penalty
    return cost, mse_loss, monotonicity_penalty, violation_count
'''
def combined_loss(outputs, targets, is_downtown, lam=0.5):
    mse_loss = nn.MSELoss()(outputs, targets)
    monotonicity_penalty = 0.0
    violation_count = 0

    # Sort the outputs and is_downtown features
    sorted_indices = torch.argsort(outputs, descending=False)
    sorted_outputs = outputs[sorted_indices]
    sorted_is_downtown = is_downtown[sorted_indices]

    for i in range(sorted_outputs.size(0)):
        for j in range(i + 1, sorted_outputs.size(0)):
            if sorted_is_downtown[j] > sorted_is_downtown[i] and sorted_outputs[j] > sorted_outputs[i]:
                monotonicity_penalty += sorted_outputs[j] - sorted_outputs[i]
                violation_count += 1

    cost = mse_loss + lam * monotonicity_penalty
    return cost, mse_loss, monotonicity_penalty, violation_count
'''

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
num_epochs = 100
lam_values = [0.0, 0.2, 0.5, 0.8, 1.0]
results = {lam: {'train_violation_count': 0, 'test_violation_count': 0, 'mape': 0, 'mse': 0} for lam in lam_values}

for lam in lam_values:
    print(f"Training with lam = {lam}")
    
    model = Net(n_features=features.shape[1], n_neurons=128, device=device, seq_len=1, pre_len=1)
    model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    
    criterion = lambda outputs, targets, is_downtown: combined_loss(outputs, targets, is_downtown, lam)
    
    best_val_loss = float('inf')
    best_model_state_dict = None
    total_train_violation_count = 0
    total_test_violation_count = 0

    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0
        train_mse_loss = 0.0
        train_monotonicity_penalty = 0.0
        train_violation_count = 0
        for inputs, targets, is_downtown_batch in train_loader:
            inputs, targets, is_downtown_batch = inputs.to(device), targets.to(device), is_downtown_batch.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss, mse_loss, monotonicity_penalty, violation_count = criterion(outputs, targets, is_downtown_batch)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
            train_mse_loss += mse_loss.item()
            train_monotonicity_penalty += monotonicity_penalty
            train_violation_count += violation_count

        train_loss /= len(train_loader)
        train_mse_loss /= len(train_loader)
        train_monotonicity_penalty /= len(train_loader)
        train_violation_count /= len(train_loader)
        total_train_violation_count += train_violation_count

        model.eval()
        with torch.no_grad():
            val_loss = 0.0
            val_mse_loss = 0.0
            val_monotonicity_penalty = 0.0
            val_violation_count = 0
            for inputs, targets, is_downtown_batch in test_loader:
                inputs, targets, is_downtown_batch = inputs.to(device), targets.to(device), is_downtown_batch.to(device)
                outputs = model(inputs)
                loss, mse_loss, monotonicity_penalty, violation_count = criterion(outputs, targets, is_downtown_batch)
                val_loss += loss.item()
                val_mse_loss += mse_loss.item()
                val_monotonicity_penalty += monotonicity_penalty
                val_violation_count += violation_count

            val_loss /= len(test_loader)
            val_mse_loss /= len(test_loader)
            val_monotonicity_penalty /= len(test_loader)
            val_violation_count /= len(test_loader)
            total_test_violation_count += val_violation_count

            if val_loss < best_val_loss:
                best_val_loss = val_loss
                best_model_state_dict = model.state_dict()

        print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Train MSE Loss: {train_mse_loss:.4f}, Train Monotonicity Penalty: {train_monotonicity_penalty:.4f}, Train Violation Count: {train_violation_count:.2f}, Val Loss: {val_loss:.4f}, Val MSE Loss: {val_mse_loss:.4f}, Val Monotonicity Penalty: {val_monotonicity_penalty:.4f}, Val Violation Count: {val_violation_count:.2f}')
      
    # Load the best model based on the validation loss
    model.load_state_dict(best_model_state_dict)
    
    # Evaluate the best model on the test set
    model.eval()
    with torch.no_grad():
        y_true = []
        y_pred = []
        for inputs, targets, _ in test_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            y_true.extend(targets.cpu().numpy())
            y_pred.extend(outputs.cpu().numpy())
    
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    y_true = target_scaler.inverse_transform(y_true.reshape(-1, 1)).flatten()
    y_pred = target_scaler.inverse_transform(y_pred.reshape(-1, 1)).flatten()
    mape = mean_absolute_percentage_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    
    results[lam]['train_violation_count'] = total_train_violation_count / num_epochs
    results[lam]['test_violation_count'] = total_test_violation_count / num_epochs
    results[lam]['mape'] = mape
    results[lam]['mse'] = mse
    
    print(f"lam = {lam} - MAPE: {mape:.4f}, MSE: {mse:.4f}")

best_lam = min(results, key=lambda x: results[x]['mape'])
print(f"Best lam: {best_lam}")
print(f"Best Model - MAPE: {results[best_lam]['mape']:.4f}, MSE: {results[best_lam]['mse']:.4f}")
print(f"Average Train Violation Count: {results[best_lam]['train_violation_count']:.2f}")
print(f"Average Test Violation Count: {results[best_lam]['test_violation_count']:.2f}")
# Out:
# Is Downtown Column Distribution:
#  is_downtown
# 0    742
# 1     29
# Name: count, dtype: int64
# Training with lam = 0.0
# Epoch [1/100], Train Loss: 0.0116, Train MSE Loss: 0.0116, Train Monotonicity Penalty: 4.1316, Train Violation Count: 75.80, Val Loss: 0.0040, Val MSE Loss: 0.0040, Val Monotonicity Penalty: 0.7320, Val Violation Count: 18.67
# Epoch [2/100], Train Loss: 0.0057, Train MSE Loss: 0.0057, Train Monotonicity Penalty: 0.4405, Train Violation Count: 12.80, Val Loss: 0.0031, Val MSE Loss: 0.0031, Val Monotonicity Penalty: 0.0371, Val Violation Count: 3.00
# Epoch [3/100], Train Loss: 0.0038, Train MSE Loss: 0.0038, Train Monotonicity Penalty: 0.0523, Train Violation Count: 1.90, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [4/100], Train Loss: 0.0034, Train MSE Loss: 0.0034, Train Monotonicity Penalty: 0.1024, Train Violation Count: 2.60, Val Loss: 0.0020, Val MSE Loss: 0.0020, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [5/100], Train Loss: 0.0027, Train MSE Loss: 0.0027, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0015, Val MSE Loss: 0.0015, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [6/100], Train Loss: 0.0024, Train MSE Loss: 0.0024, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0013, Val MSE Loss: 0.0013, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [7/100], Train Loss: 0.0023, Train MSE Loss: 0.0023, Train Monotonicity Penalty: 0.1265, Train Violation Count: 3.10, Val Loss: 0.0012, Val MSE Loss: 0.0012, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [8/100], Train Loss: 0.0019, Train MSE Loss: 0.0019, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0011, Val MSE Loss: 0.0011, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [9/100], Train Loss: 0.0020, Train MSE Loss: 0.0020, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0011, Val MSE Loss: 0.0011, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [10/100], Train Loss: 0.0018, Train MSE Loss: 0.0018, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [11/100], Train Loss: 0.0019, Train MSE Loss: 0.0019, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0011, Val MSE Loss: 0.0011, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [12/100], Train Loss: 0.0020, Train MSE Loss: 0.0020, Train Monotonicity Penalty: 0.0002, Train Violation Count: 0.10, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [13/100], Train Loss: 0.0022, Train MSE Loss: 0.0022, Train Monotonicity Penalty: 0.5645, Train Violation Count: 18.40, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [14/100], Train Loss: 0.0018, Train MSE Loss: 0.0018, Train Monotonicity Penalty: 0.0032, Train Violation Count: 0.10, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [15/100], Train Loss: 0.0020, Train MSE Loss: 0.0020, Train Monotonicity Penalty: 0.1299, Train Violation Count: 4.30, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [16/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [17/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.0001, Train Violation Count: 0.10, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [18/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [19/100], Train Loss: 0.0018, Train MSE Loss: 0.0018, Train Monotonicity Penalty: 0.3292, Train Violation Count: 9.00, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [20/100], Train Loss: 0.0017, Train MSE Loss: 0.0017, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [21/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.0036, Train Violation Count: 0.10, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [22/100], Train Loss: 0.0018, Train MSE Loss: 0.0018, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [23/100], Train Loss: 0.0017, Train MSE Loss: 0.0017, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [24/100], Train Loss: 0.0018, Train MSE Loss: 0.0018, Train Monotonicity Penalty: 0.0013, Train Violation Count: 0.10, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [25/100], Train Loss: 0.0015, Train MSE Loss: 0.0015, Train Monotonicity Penalty: 0.0116, Train Violation Count: 0.20, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [26/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.1157, Train Violation Count: 3.90, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [27/100], Train Loss: 0.0017, Train MSE Loss: 0.0017, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [28/100], Train Loss: 0.0018, Train MSE Loss: 0.0018, Train Monotonicity Penalty: 0.0067, Train Violation Count: 0.30, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [29/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.0054, Train Violation Count: 0.10, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [30/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.0032, Train Violation Count: 0.10, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [31/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [32/100], Train Loss: 0.0018, Train MSE Loss: 0.0018, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [33/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.0049, Train Violation Count: 0.10, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [34/100], Train Loss: 0.0017, Train MSE Loss: 0.0017, Train Monotonicity Penalty: 0.0009, Train Violation Count: 0.10, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [35/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [36/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.0045, Train Violation Count: 0.40, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [37/100], Train Loss: 0.0017, Train MSE Loss: 0.0017, Train Monotonicity Penalty: 0.0030, Train Violation Count: 0.10, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [38/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [39/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0011, Val MSE Loss: 0.0011, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [40/100], Train Loss: 0.0018, Train MSE Loss: 0.0018, Train Monotonicity Penalty: 0.0017, Train Violation Count: 0.10, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [41/100], Train Loss: 0.0020, Train MSE Loss: 0.0020, Train Monotonicity Penalty: 0.1020, Train Violation Count: 3.60, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [42/100], Train Loss: 0.0015, Train MSE Loss: 0.0015, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [43/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.0027, Train Violation Count: 0.20, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [44/100], Train Loss: 0.0017, Train MSE Loss: 0.0017, Train Monotonicity Penalty: 0.0070, Train Violation Count: 0.10, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [45/100], Train Loss: 0.0017, Train MSE Loss: 0.0017, Train Monotonicity Penalty: 0.0062, Train Violation Count: 0.10, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [46/100], Train Loss: 0.0017, Train MSE Loss: 0.0017, Train Monotonicity Penalty: 0.1447, Train Violation Count: 4.20, Val Loss: 0.0011, Val MSE Loss: 0.0011, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [47/100], Train Loss: 0.0017, Train MSE Loss: 0.0017, Train Monotonicity Penalty: 0.0112, Train Violation Count: 0.30, Val Loss: 0.0012, Val MSE Loss: 0.0012, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [48/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0012, Val MSE Loss: 0.0012, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [49/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.0023, Train Violation Count: 0.10, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [50/100], Train Loss: 0.0017, Train MSE Loss: 0.0017, Train Monotonicity Penalty: 0.0035, Train Violation Count: 0.10, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [51/100], Train Loss: 0.0017, Train MSE Loss: 0.0017, Train Monotonicity Penalty: 0.0034, Train Violation Count: 0.10, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [52/100], Train Loss: 0.0017, Train MSE Loss: 0.0017, Train Monotonicity Penalty: 0.1082, Train Violation Count: 4.30, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [53/100], Train Loss: 0.0015, Train MSE Loss: 0.0015, Train Monotonicity Penalty: 0.0038, Train Violation Count: 0.10, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [54/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [55/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [56/100], Train Loss: 0.0015, Train MSE Loss: 0.0015, Train Monotonicity Penalty: 0.0051, Train Violation Count: 0.20, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [57/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [58/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.1594, Train Violation Count: 4.70, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [59/100], Train Loss: 0.0020, Train MSE Loss: 0.0020, Train Monotonicity Penalty: 0.0038, Train Violation Count: 0.10, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [60/100], Train Loss: 0.0022, Train MSE Loss: 0.0022, Train Monotonicity Penalty: 0.1996, Train Violation Count: 5.20, Val Loss: 0.0011, Val MSE Loss: 0.0011, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [61/100], Train Loss: 0.0018, Train MSE Loss: 0.0018, Train Monotonicity Penalty: 0.0030, Train Violation Count: 0.10, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [62/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [63/100], Train Loss: 0.0015, Train MSE Loss: 0.0015, Train Monotonicity Penalty: 0.0059, Train Violation Count: 0.10, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [64/100], Train Loss: 0.0017, Train MSE Loss: 0.0017, Train Monotonicity Penalty: 0.0028, Train Violation Count: 0.10, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [65/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.0038, Train Violation Count: 0.10, Val Loss: 0.0011, Val MSE Loss: 0.0011, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [66/100], Train Loss: 0.0017, Train MSE Loss: 0.0017, Train Monotonicity Penalty: 0.0831, Train Violation Count: 3.00, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [67/100], Train Loss: 0.0017, Train MSE Loss: 0.0017, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [68/100], Train Loss: 0.0015, Train MSE Loss: 0.0015, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [69/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.0024, Train Violation Count: 0.10, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [70/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [71/100], Train Loss: 0.0035, Train MSE Loss: 0.0035, Train Monotonicity Penalty: 0.0646, Train Violation Count: 2.80, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [72/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.0053, Train Violation Count: 0.20, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [73/100], Train Loss: 0.0015, Train MSE Loss: 0.0015, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [74/100], Train Loss: 0.0015, Train MSE Loss: 0.0015, Train Monotonicity Penalty: 0.0043, Train Violation Count: 0.10, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [75/100], Train Loss: 0.0020, Train MSE Loss: 0.0020, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [76/100], Train Loss: 0.0015, Train MSE Loss: 0.0015, Train Monotonicity Penalty: 0.0047, Train Violation Count: 0.10, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [77/100], Train Loss: 0.0015, Train MSE Loss: 0.0015, Train Monotonicity Penalty: 0.1262, Train Violation Count: 3.90, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [78/100], Train Loss: 0.0018, Train MSE Loss: 0.0018, Train Monotonicity Penalty: 0.1527, Train Violation Count: 4.50, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [79/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [80/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [81/100], Train Loss: 0.0015, Train MSE Loss: 0.0015, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [82/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.0035, Train Violation Count: 0.20, Val Loss: 0.0012, Val MSE Loss: 0.0012, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [83/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.0077, Train Violation Count: 0.20, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [84/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [85/100], Train Loss: 0.0015, Train MSE Loss: 0.0015, Train Monotonicity Penalty: 0.1360, Train Violation Count: 4.70, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [86/100], Train Loss: 0.0017, Train MSE Loss: 0.0017, Train Monotonicity Penalty: 0.0780, Train Violation Count: 2.80, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [87/100], Train Loss: 0.0015, Train MSE Loss: 0.0015, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [88/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.1588, Train Violation Count: 4.50, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [89/100], Train Loss: 0.0015, Train MSE Loss: 0.0015, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [90/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.0090, Train Violation Count: 0.20, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [91/100], Train Loss: 0.0015, Train MSE Loss: 0.0015, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [92/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0011, Val MSE Loss: 0.0011, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [93/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0011, Val MSE Loss: 0.0011, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [94/100], Train Loss: 0.0017, Train MSE Loss: 0.0017, Train Monotonicity Penalty: 0.0027, Train Violation Count: 0.10, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [95/100], Train Loss: 0.0017, Train MSE Loss: 0.0017, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [96/100], Train Loss: 0.0017, Train MSE Loss: 0.0017, Train Monotonicity Penalty: 0.0155, Train Violation Count: 0.20, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [97/100], Train Loss: 0.0015, Train MSE Loss: 0.0015, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [98/100], Train Loss: 0.0015, Train MSE Loss: 0.0015, Train Monotonicity Penalty: 0.0015, Train Violation Count: 0.10, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [99/100], Train Loss: 0.0015, Train MSE Loss: 0.0015, Train Monotonicity Penalty: 0.0077, Train Violation Count: 0.30, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [100/100], Train Loss: 0.0015, Train MSE Loss: 0.0015, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# lam = 0.0 - MAPE: 12.1418, MSE: 2985564672.0000
# Training with lam = 0.2
# Epoch [1/100], Train Loss: 1.3141, Train MSE Loss: 0.0172, Train Monotonicity Penalty: 6.4846, Train Violation Count: 53.00, Val Loss: 0.0082, Val MSE Loss: 0.0046, Val Monotonicity Penalty: 0.0179, Val Violation Count: 1.67
# Epoch [2/100], Train Loss: 0.1057, Train MSE Loss: 0.0072, Train Monotonicity Penalty: 0.4927, Train Violation Count: 5.00, Val Loss: 0.0054, Val MSE Loss: 0.0054, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [3/100], Train Loss: 0.0096, Train MSE Loss: 0.0084, Train Monotonicity Penalty: 0.0060, Train Violation Count: 0.20, Val Loss: 0.0078, Val MSE Loss: 0.0078, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [4/100], Train Loss: 0.0123, Train MSE Loss: 0.0110, Train Monotonicity Penalty: 0.0064, Train Violation Count: 0.20, Val Loss: 0.0092, Val MSE Loss: 0.0092, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [5/100], Train Loss: 0.0116, Train MSE Loss: 0.0116, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0087, Val MSE Loss: 0.0087, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [6/100], Train Loss: 0.0116, Train MSE Loss: 0.0108, Train Monotonicity Penalty: 0.0040, Train Violation Count: 0.10, Val Loss: 0.0078, Val MSE Loss: 0.0078, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [7/100], Train Loss: 0.0118, Train MSE Loss: 0.0100, Train Monotonicity Penalty: 0.0093, Train Violation Count: 0.20, Val Loss: 0.0070, Val MSE Loss: 0.0070, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [8/100], Train Loss: 0.0093, Train MSE Loss: 0.0093, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.
Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# lam = 0.2 - MAPE: 18.6839, MSE: 4769051136.0000
# Training with lam = 0.5
# Epoch [1/100], Train Loss: 4.9628, Train MSE Loss: 0.0130, Train Monotonicity Penalty: 9.8995, Train Violation Count: 78.90, Val Loss: 0.1359, Val MSE Loss: 0.0070, Val Monotonicity Penalty: 0.2578, Val Violation Count: 4.67
# Epoch [2/100], Train Loss: 0.1208, Train MSE Loss: 0.0131, Train Monotonicity Penalty: 0.2153, Train Violation Count: 3.30, Val Loss: 0.0801, Val MSE Loss: 0.0137, Val Monotonicity Penalty: 0.1329, Val Violation Count: 2.00
# Epoch [3/100], Train Loss: 0.0798, Train MSE Loss: 0.0184, Train Monotonicity Penalty: 0.1229, Train Violation Count: 1.80, Val Loss: 0.0665, Val MSE Loss: 0.0153, Val Monotonicity Penalty: 0.1023, Val Violation Count: 1.67
# Epoch [4/100], Train Loss: 0.0404, Train MSE Loss: 0.0179, Train Monotonicity Penalty: 0.0451, Train Violation Count: 0.90, Val Loss: 0.0568, Val MSE Loss: 0.0146, Val Monotonicity Penalty: 0.0845, Val Violation Count: 1.33
# Epoch [5/100], Train Loss: 0.0391, Train MSE Loss: 0.0169, Train Monotonicity Penalty: 0.0443, Train Violation Count: 1.20, Val Loss: 0.0467, Val MSE Loss: 0.0132, Val Monotonicity Penalty: 0.0669, Val Violation Count: 1.00
# Epoch [6/100], Train Loss: 0.0222, Train MSE Loss: 0.0157, Train Monotonicity Penalty: 0.0130, Train Violation Count: 0.50, Val Loss: 0.0397, Val MSE Loss: 0.0123, Val Monotonicity Penalty: 0.0548, Val Violation Count: 1.00
# Epoch [7/100], Train Loss: 0.0203, Train MSE Loss: 0.0153, Train Monotonicity Penalty: 0.0102, Train Violation Count: 0.20, Val Loss: 0.0352, Val MSE Loss: 0.0119, Val Monotonicity Penalty: 0.0465, Val Violation Count: 1.00
# Epoch [8/100], Train Loss: 0.0244, Train MSE Loss: 0.0143, Train Monotonicity Penalty: 0.0202, Train Violation Count: 0.50, Val Loss: 0.0308, Val MSE Loss: 0.0116, Val Monotonicity Penalty: 0.0383, Val Violation Count: 1.00
# Epoch [9/100], Train Loss: 0.0168, Train MSE Loss: 0.0142, Train Monotonicity Penalty: 0.0051, Train Violation Count: 0.30, Val Loss: 0.0272, Val MSE Loss: 0.0114, Val Monotonicity Penalty: 0.0318, Val Violation Count: 1.00
# Epoch [10/100], Train Loss: 0.0176, Train MSE Loss: 0.0138, Train Monotonicity Penalty: 0.0074, Train Violation Count: 0.30, Val Loss: 0.0240, Val MSE Loss: 0.0111, Val Monotonicity Penalty: 0.0259, Val Violation Count: 1.00
# Epoch [11/100], Train Loss: 0.0171, Train MSE Loss: 0.0135, Train Monotonicity Penalty: 0.0072, Train Violation Count: 0.10, Val Loss: 0.0209, Val MSE Loss: 0.0108, Val Monotonicity Penalty: 0.0202, Val Violation Count: 1.00
# Epoch [12/100], Train Loss: 0.1785, Train MSE Loss: 0.0128, Train Monotonicity Penalty: 0.3314, Train Violation Count: 3.20, Val Loss: 0.0163, Val MSE Loss: 0.0118, Val Monotonicity Penalty: 0.0091, Val Violation Count: 0.67
# ...
# Epoch [31/100], Train Loss: 0.0087, Train MSE Loss: 0.0087, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0061, Val MSE Loss: 0.0061, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch
Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0016, Val MSE Loss: 0.0016, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [59/100], Train Loss: 0.0500, Train MSE Loss: 0.0082, Train Monotonicity Penalty: 0.0419, Train Violation Count: 2.00, Val Loss: 0.0212, Val MSE Loss: 0.0212, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [60/100], Train Loss: 0.0336, Train MSE Loss: 0.0328, Train Monotonicity Penalty: 0.0008, Train Violation Count: 0.10, Val Loss: 0.0361, Val MSE Loss: 0.0361, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [61/100], Train Loss: 0.0376, Train MSE Loss: 0.0352, Train Monotonicity Penalty: 0.0025, Train Violation Count: 0.10, Val Loss: 0.0275, Val MSE Loss: 0.0275, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [62/100], Train Loss: 0.0244, Train MSE Loss: 0.0244, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0166, Val MSE Loss: 0.0166, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [63/100], Train Loss: 0.0146, Train MSE Loss: 0.0146, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0091, Val MSE Loss: 0.0091, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [64/100], Train Loss: 0.0084, Train MSE Loss: 0.0084, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0049, Val MSE Loss: 0.0049, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [65/100], Train Loss: 0.0051, Train MSE Loss: 0.0051, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0028, Val MSE Loss: 0.0028, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [66/100], Train Loss: 0.0036, Train MSE Loss: 0.0036, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0018, Val MSE Loss: 0.0018, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [67/100], Train Loss: 0.0028, Train MSE Loss: 0.0028, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0014, Val MSE Loss: 0.0014, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [68/100], Train Loss: 0.0025, Train MSE Loss: 0.0025, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0013, Val MSE Loss: 0.0013, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [69/100], Train Loss: 0.0027, Train MSE Loss: 0.0027, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0012, Val MSE Loss: 0.0012, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [70/100], Train Loss: 0.0022, Train MSE Loss: 0.0022, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0012, Val MSE Loss: 0.0012, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [71/100], Train Loss: 0.0024, Train MSE Loss: 0.0024, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0012, Val MSE Loss: 0.0012, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [72/100], Train Loss: 0.1471, Train MSE Loss: 0.0119, Train Monotonicity Penalty: 0.1352, Train Violation Count: 3.80, Val Loss: 0.0514, Val MSE Loss: 0.0514, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [73/100], Train Loss: 0.1869, Train MSE Loss: 0.0885, Train Monotonicity Penalty: 0.0985, Train Violation Count: 1.10, Val Loss: 0.0900, Val MSE Loss: 0.0900, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [74/100], Train Loss: 0.0937, Train MSE Loss: 0.0684, Train Monotonicity Penalty: 0.0254, Train Violation Count: 0.50, Val Loss: 0.0410, Val MSE Loss: 0.0410, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [75/100], Train Loss: 0.0308, Train MSE Loss: 0.0291, Train Monotonicity Penalty: 0.0016, Train Violation Count: 0.10, Val Loss: 0.0155, Val MSE Loss: 0.0155, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [76/100], Train Loss: 0.0123, Train MSE Loss: 0.0123, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0065, Val MSE Loss: 0.0065, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [77/100], Train Loss: 0.0061, Train MSE Loss: 0.0061, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0033, Val MSE Loss: 0.0033, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [78/100], Train Loss: 0.0039, Train MSE Loss: 0.0039, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0021, Val MSE Loss: 0.0021, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [79/100], Train Loss: 0.0031, Train MSE Loss: 0.0031, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0017, Val MSE Loss: 0.0017, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [80/100], Train Loss: 0.0592, Train MSE Loss: 0.0117, Train Monotonicity Penalty: 0.0475, Train Violation Count: 1.60, Val Loss: 0.0217, Val MSE Loss: 0.0217, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [81/100], Train Loss: 0.0281, Train MSE Loss: 0.0281, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0284, Val MSE Loss: 0.0284, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [82/100], Train Loss: 0.0282, Train MSE Loss: 0.0282, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0224, Val MSE Loss: 0.0224, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [83/100], Train Loss: 0.0210, Train MSE Loss: 0.0210, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0144, Val MSE Loss: 0.0144, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [84/100], Train Loss: 0.0131, Train MSE Loss: 0.0131, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0084, Val MSE Loss: 0.0084, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [85/100], Train Loss: 0.0080, Train MSE Loss: 0.0080, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0048, Val MSE Loss: 0.0048, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [86/100], Train Loss: 0.0123, Train MSE Loss: 0.0062, Train Monotonicity Penalty: 0.0060, Train Violation Count: 0.30, Val Loss: 0.0052, Val MSE Loss: 0.0052, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [87/100], Train Loss: 0.0165, Train MSE Loss: 0.0088, Train Monotonicity Penalty: 0.0077, Train Violation Count: 0.70, Val Loss: 0.0111, Val MSE Loss: 0.0111, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [88/100], Train Loss: 0.0155, Train MSE Loss: 0.0155, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0149, Val MSE Loss: 0.0149, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [89/100], Train Loss: 0.0152, Train MSE Loss: 0.0152, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0118, Val MSE Loss: 0.0118, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [90/100], Train Loss: 0.0116, Train MSE Loss: 0.0116, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0077, Val MSE Loss: 0.0077, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [91/100], Train Loss: 0.0076, Train MSE Loss: 0.0076, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0046, Val MSE Loss: 0.0046, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [92/100], Train Loss: 0.0222, Train MSE Loss: 0.0066, Train Monotonicity Penalty: 0.0156, Train Violation Count: 0.70, Val Loss: 0.0080, Val MSE Loss: 0.0080, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [93/100], Train Loss: 0.0162, Train MSE Loss: 0.0117, Train Monotonicity Penalty: 0.0045, Train Violation Count: 0.20, Val Loss: 0.0126, Val MSE Loss: 0.0126, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [94/100], Train Loss: 0.0147, Train MSE Loss: 0.0147, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0121, Val MSE Loss: 0.0121, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [95/100], Train Loss: 0.0119, Train MSE Loss: 0.0119, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0084, Val MSE Loss: 0.0084, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [96/100], Train Loss: 0.0082, Train MSE Loss: 0.0082, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0052, Val MSE Loss: 0.0052, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [97/100], Train Loss: 0.0056, Train MSE Loss: 0.0056, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0031, Val MSE Loss: 0.0031, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [98/100], Train Loss: 0.0039, Train MSE Loss: 0.0039, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0021, Val MSE Loss: 0.0021, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [99/100], Train Loss: 0.0031, Train MSE Loss: 0.0031, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0016, Val MSE Loss: 0.0016, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [100/100], Train Loss: 0.0028, Train MSE Loss: 0.0028, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0014, Val MSE Loss: 0.0014, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# lam = 1.0 - MAPE: 14.8564, MSE: 3894277632.0000
# Best lam: 0.5
# Best Model - MAPE: 9.8191, MSE: 3905472000.0000
# Average Train Violation Count: 1.09
# Average Test Violation Count: 0.18

# %%
# Print the unique tract IDs in the merged dataframe
print("Unique Tract IDs in the merged dataframe:")
print(merged_df.index.unique())

# Print the format of the tract IDs in the downtown_areas list
print("\nThe Tract IDs of the downtown_areas list:")
for tract_id in downtown_areas:
    print(tract_id)
# Out:
# Unique Tract IDs in the merged dataframe:
# Index([17031010100, 17031010201, 17031010202, 17031010300, 17031010400,
#        17031010501, 17031010502, 17031010503, 17031010600, 17031010701,
#        ...
#        17031843000, 17031843100, 17031843200, 17031843300, 17031843400,
#        17031843500, 17031843600, 17031843700, 17031843800, 17031843900],
#       dtype='int64', name='index', length=771)
#
# Format of Tract IDs in the downtown_areas list:
# 17031839000
# 17031080202
# 17031833000
# 17031833100
# 17031839100
# 17031081201
# 17031080201
# 17031081202
# 17031842200
# 17031838300
# 17031081401
# 17031081403
# 17031081300
# 17031081100
# 17031080300
# 17031080100
# 17031080400
# 17031081000
# 17031320400
# 17031320600
# 17031081402
# 17031320100
# 17031081900
# 17031081500
# 17031081800
# 17031081600
# 17031081700
# 17031280100
# 17031281900
