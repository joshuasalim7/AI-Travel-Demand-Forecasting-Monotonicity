# %%
# MLP Model w 2 Hidden Layers, dropout rate = 0.01, learning rate = 0.01, Adam optimizer
# Input layer --> 2 Hidden Layers (each w Linear, ReLU, Dropout) --> Output layer

import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error
from sklearn.preprocessing import MinMaxScaler
import random

# Set random seed for reproducibility
random_seed = 42
random.seed(random_seed)
np.random.seed(random_seed)
torch.manual_seed(random_seed)
torch.cuda.manual_seed_all(random_seed)

# Load the data
merged_downtown_data = pd.read_csv('./merged_downtown_data.csv')
ridesourcing_data = pd.read_csv("./Ridesourcing_CensusCount_ALL_0_Filled.csv")

# Renaming and setting index for merging
merged_downtown_data = merged_downtown_data.rename(columns={"TractID": "index"})
merged_downtown_data.set_index("index", inplace=True)
ridesourcing_data.set_index("index", inplace=True)

# Merging the dataframes
merged_df = merged_downtown_data.join(ridesourcing_data, how='inner')

# Dropping the unnecessary columns
columns_to_drop = ["Unnamed: 0", "X", "Y"]
merged_df = merged_df.drop(columns=columns_to_drop)

# Create the "is_downtown" column
downtown_areas = [
    '17031839000', '17031080202', '17031833000', '17031833100', '17031839100', 
    '17031081201', '17031080201', '17031081202', '17031842200', '17031838300', 
    '17031081401', '17031081403', '17031081300', '17031081100', '17031080300', 
    '17031080100', '17031080400', '17031081000', '17031320400', '17031320600', 
    '17031081402', '17031320100', '17031081900', '17031081500', '17031081800', 
    '17031081600', '17031081700', '17031280100', '17031281900'
]

downtown_areas = [int(tract_id) for tract_id in downtown_areas]
merged_df['is_downtown'] = merged_df.index.isin(downtown_areas).astype(int)

# Verify the 'is_downtown' column
print("Is Downtown Column Distribution:\n", merged_df['is_downtown'].value_counts())

# Aggregate the travel demand by summing across all time columns
ridesourcing_data_aggregated = ridesourcing_data.sum(axis=1)

# Splitting the data into features and aggregated target
features = merged_df.drop(columns=ridesourcing_data.columns)
target = ridesourcing_data_aggregated

# Create MinMaxScaler instances for features and target
feature_scaler = MinMaxScaler()
target_scaler = MinMaxScaler()

# Fit and transform the features and target
features_scaled = feature_scaler.fit_transform(features)
target_scaled = target_scaler.fit_transform(target.values.reshape(-1, 1)).flatten()

# Use stratified sampling to split the data
train_indices, test_indices = train_test_split(range(len(features_scaled)), test_size=0.2, stratify=merged_df['is_downtown'])
X_train, X_test = features_scaled[train_indices], features_scaled[test_indices]
y_train, y_test = target_scaled[train_indices], target_scaled[test_indices]
is_downtown_train = merged_df['is_downtown'].iloc[train_indices].to_numpy().astype(float)
is_downtown_test = merged_df['is_downtown'].iloc[test_indices].to_numpy().astype(float)

# Define the PyTorch dataset and dataloader
class TravelDataset(Dataset):
    def __init__(self, X, y, is_downtown):
        self.X = X
        self.y = y
        self.is_downtown = is_downtown

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        x = self.X[idx, :].astype(np.float32)
        y = np.array(self.y[idx], dtype=np.float32)
        is_downtown = np.array(self.is_downtown[idx], dtype=np.float32)
        return torch.from_numpy(x), torch.from_numpy(y), torch.from_numpy(is_downtown)

train_dataset = TravelDataset(X_train, y_train, is_downtown_train)
test_dataset = TravelDataset(X_test, y_test, is_downtown_test)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# Define the Net model
class Net(nn.Module):
    def __init__(self, n_features, n_neurons, device, seq_len, pre_len):
        super(Net, self).__init__()
        self.flatten = nn.Flatten()
        self.device = device
        self.n_features = n_features
        self.n_neurons = n_neurons
        self.seq_len = seq_len
        self.pre_len = pre_len
        
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(n_features, n_neurons),
            nn.ReLU(),
            nn.Dropout(p=0.01),
            nn.Linear(n_neurons, n_neurons),
            nn.ReLU(),
            nn.Dropout(p=0.01),
            nn.Linear(n_neurons, pre_len),
            nn.ReLU(),
            nn.Dropout(p=0.01),
        )

    def forward(self, x):
        pred = self.linear_relu_stack(x).to(self.device)
        return pred.squeeze()

def combined_loss(outputs, targets, is_downtown, lam=0.5):
    mse_loss = nn.MSELoss()(outputs, targets)
    monotonicity_penalty = 0.0
    violation_count = 0

    # Efficiently compute monotonicity penalty
    for i in range(len(outputs)):
        for j in range(len(outputs)):
            if is_downtown[i] > is_downtown[j] and outputs[i] < outputs[j]:
                monotonicity_penalty += (outputs[j] - outputs[i]).item()
                violation_count += 1

    cost = mse_loss + lam * monotonicity_penalty
    return cost, mse_loss, monotonicity_penalty, violation_count

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
num_epochs = 100
lam_values = [0.0, 0.2, 0.5, 0.8, 1.0]
results = {lam: {'train_violation_count': 0, 'test_violation_count': 0, 'mape': 0, 'mse': 0, 'mae': 0, 'rmse': 0} for lam in lam_values}

for lam in lam_values:
    print(f"Training with lam = {lam}")
    
    model = Net(n_features=features.shape[1], n_neurons=256, device=device, seq_len=1, pre_len=1)
    model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    
    criterion = lambda outputs, targets, is_downtown: combined_loss(outputs, targets, is_downtown, lam)
    
    best_val_loss = float('inf')
    best_model_state_dict = None
    total_train_violation_count = 0
    total_test_violation_count = 0

    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0
        train_mse_loss = 0.0
        train_monotonicity_penalty = 0.0
        train_violation_count = 0
        for inputs, targets, is_downtown_batch in train_loader:
            inputs, targets, is_downtown_batch = inputs.to(device), targets.to(device), is_downtown_batch.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss, mse_loss, monotonicity_penalty, violation_count = criterion(outputs, targets, is_downtown_batch)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
            train_mse_loss += mse_loss.item()
            train_monotonicity_penalty += monotonicity_penalty
            train_violation_count += violation_count

        train_loss /= len(train_loader)
        train_mse_loss /= len(train_loader)
        train_monotonicity_penalty /= len(train_loader)
        train_violation_count /= len(train_loader)
        total_train_violation_count += train_violation_count

        model.eval()
        with torch.no_grad():
            val_loss = 0.0
            val_mse_loss = 0.0
            val_monotonicity_penalty = 0.0
            val_violation_count = 0
            for inputs, targets, is_downtown_batch in test_loader:
                inputs, targets, is_downtown_batch = inputs.to(device), targets.to(device), is_downtown_batch.to(device)
                outputs = model(inputs)
                loss, mse_loss, monotonicity_penalty, violation_count = criterion(outputs, targets, is_downtown_batch)
                val_loss += loss.item()
                val_mse_loss += mse_loss.item()
                val_monotonicity_penalty += monotonicity_penalty
                val_violation_count += violation_count

            val_loss /= len(test_loader)
            val_mse_loss /= len(test_loader)
            val_monotonicity_penalty /= len(test_loader)
            val_violation_count /= len(test_loader)
            total_test_violation_count += val_violation_count

            if val_loss < best_val_loss:
                best_val_loss = val_loss
                best_model_state_dict = model.state_dict()

        print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Train MSE Loss: {train_mse_loss:.4f}, Train Monotonicity Penalty: {train_monotonicity_penalty:.4f}, Train Violation Count: {train_violation_count:.2f}, Val Loss: {val_loss:.4f}, Val MSE Loss: {val_mse_loss:.4f}, Val Monotonicity Penalty: {val_monotonicity_penalty:.4f}, Val Violation Count: {val_violation_count:.2f}')
      
    # Load the best model based on the validation loss
    model.load_state_dict(best_model_state_dict)
    
    # Evaluate the best model on the test set
    model.eval()
    with torch.no_grad():
        y_true = []
        y_pred = []
        for inputs, targets, _ in test_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            y_true.extend(targets.cpu().numpy())
            y_pred.extend(outputs.cpu().numpy())
    
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    y_true = target_scaler.inverse_transform(y_true.reshape(-1, 1)).flatten()
    y_pred = target_scaler.inverse_transform(y_pred.reshape(-1, 1)).flatten()
    mape = mean_absolute_percentage_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    
    results[lam]['train_violation_count'] = total_train_violation_count / num_epochs
    results[lam]['test_violation_count'] = total_test_violation_count / num_epochs
    results[lam]['mape'] = mape
    results[lam]['mse'] = mse
    results[lam]['mae'] = mae
    results[lam]['rmse'] = rmse
    
    print(f"lam = {lam} - MAPE: {mape:.4f}, MSE: {mse:.4f}, MAE: {mae:.4f}, RMSE: {rmse:.4f}")

best_lam = min(results, key=lambda x: results[x]['mape'])
print(f"Best lam: {best_lam}")
print(f"Best Model - MAPE: {results[best_lam]['mape']:.4f}, MSE: {results[best_lam]['mse']:.4f}, MAE: {results[best_lam]['mae']:.4f}, RMSE: {results[best_lam]['rmse']:.4f}")
print(f"Average Train Violation Count: {results[best_lam]['train_violation_count']:.2f}")
print(f"Average Test Violation Count: {results[best_lam]['test_violation_count']:.2f}")
# Out:
# Is Downtown Column Distribution:
#  is_downtown
# 0    742
# 1     29
# Name: count, dtype: int64
# Training with lam = 0.0
# Epoch [1/100], Train Loss: 0.0038, Train MSE Loss: 0.0038, Train Monotonicity Penalty: 0.4718, Train Violation Count: 17.80, Val Loss: 0.0011, Val MSE Loss: 0.0011, Val Monotonicity Penalty: 0.0003, Val Violation Count: 0.33
# Epoch [2/100], Train Loss: 0.0018, Train MSE Loss: 0.0018, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0023, Val MSE Loss: 0.0023, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [3/100], Train Loss: 0.0019, Train MSE Loss: 0.0019, Train Monotonicity Penalty: 0.0077, Train Violation Count: 0.20, Val Loss: 0.0019, Val MSE Loss: 0.0019, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [4/100], Train Loss: 0.0012, Train MSE Loss: 0.0012, Train Monotonicity Penalty: 0.0003, Train Violation Count: 0.10, Val Loss: 0.0018, Val MSE Loss: 0.0018, Val Monotonicity Penalty: 0.0007, Val Violation Count: 0.67
# Epoch [5/100], Train Loss: 0.0012, Train MSE Loss: 0.0012, Train Monotonicity Penalty: 0.0421, Train Violation Count: 0.90, Val Loss: 0.0014, Val MSE Loss: 0.0014, Val Monotonicity Penalty: 0.0511, Val Violation Count: 1.33
# Epoch [6/100], Train Loss: 0.0011, Train MSE Loss: 0.0011, Train Monotonicity Penalty: 0.0548, Train Violation Count: 1.10, Val Loss: 0.0014, Val MSE Loss: 0.0014, Val Monotonicity Penalty: 0.0180, Val Violation Count: 0.67
# Epoch [7/100], Train Loss: 0.0010, Train MSE Loss: 0.0010, Train Monotonicity Penalty: 0.0359, Train Violation Count: 0.60, Val Loss: 0.0016, Val MSE Loss: 0.0016, Val Monotonicity Penalty: 0.0122, Val Violation Count: 0.67
# Epoch [8/100], Train Loss: 0.0009, Train MSE Loss: 0.0009, Train Monotonicity Penalty: 0.1122, Train Violation Count: 1.70, Val Loss: 0.0016, Val MSE Loss: 0.0016, Val Monotonicity Penalty: 0.0323, Val Violation Count: 1.33
# Epoch [9/100], Train Loss: 0.0010, Train MSE Loss: 0.0010, Train Monotonicity Penalty: 0.0124, Train Violation Count: 0.60, Val Loss: 0.0015, Val MSE Loss: 0.0015, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [10/100], Train Loss: 0.0010, Train MSE Loss: 0.0010, Train Monotonicity Penalty: 0.0858, Train Violation Count: 1.00, Val Loss: 0.0012, Val MSE Loss: 0.0012, Val Monotonicity Penalty: 0.0187, Val Violation Count: 1.00
# Epoch [11/100], Train Loss: 0.0008, Train MSE Loss: 0.0008, Train Monotonicity Penalty: 0.0277, Train Violation Count: 0.40, Val Loss: 0.0012, Val MSE Loss: 0.0012, Val Monotonicity Penalty: 0.0145, Val Violation Count: 0.67
# Epoch [12/100], Train Loss: 0.0007, Train MSE Loss: 0.0007, Train Monotonicity Penalty: 0.0734, Train Violation Count: 1.10, Val Loss: 0.0011, Val MSE Loss: 0.0011, Val Monotonicity Penalty: 0.0162, Val Violation Count: 0.67
# Epoch [13/100], Train Loss: 0.0006, Train MSE Loss: 0.0006, Train Monotonicity Penalty: 0.0941, Train Violation Count: 1.70, Val Loss: 0.0008, Val MSE Loss: 0.0008, Val Monotonicity Penalty: 0.0444, Val Violation Count: 1.67
# Epoch [14/100], Train Loss: 0.0006, Train MSE Loss: 0.0006, Train Monotonicity Penalty: 0.0650, Train Violation Count: 2.00, Val Loss: 0.0013, Val MSE Loss: 0.0013, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [15/100], Train Loss: 0.0022, Train MSE Loss: 0.0022, Train Monotonicity Penalty: 0.0272, Train Violation Count: 1.20, Val Loss: 0.0011, Val MSE Loss: 0.0011, Val Monotonicity Penalty: 0.0042, Val Violation Count: 0.33
# Epoch [16/100], Train Loss: 0.0007, Train MSE Loss: 0.0007, Train Monotonicity Penalty: 0.0540, Train Violation Count: 0.50, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0023, Val Violation Count: 0.33
# Epoch [17/100], Train Loss: 0.0005, Train MSE Loss: 0.0005, Train Monotonicity Penalty: 0.0246, Train Violation Count: 1.00, Val Loss: 0.0011, Val MSE Loss: 0.0011, Val Monotonicity Penalty: 0.0203, Val Violation Count: 1.67
# Epoch [18/100], Train Loss: 0.0005, Train MSE Loss: 0.0005, Train Monotonicity Penalty: 0.0751, Train Violation Count: 1.30, Val Loss: 0.0011, Val MSE Loss: 0.0011, Val Monotonicity Penalty: 0.0123, Val Violation Count: 1.33
# Epoch [19/100], Train Loss: 0.0006, Train MSE Loss: 0.0006, Train Monotonicity Penalty: 0.0397, Train Violation Count: 0.80, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0538, Val Violation Count: 2.00
# Epoch [20/100], Train Loss: 0.0004, Train MSE Loss: 0.0004, Train Monotonicity Penalty: 0.0590, Train Violation Count: 1.20, Val Loss: 0.0008, Val MSE Loss: 0.0008, Val Monotonicity Penalty: 0.0816, Val Violation Count: 2.33
# Epoch [21/100], Train Loss: 0.0004, Train MSE Loss: 0.0004, Train Monotonicity Penalty: 0.0986, Train Violation Count: 1.90, Val Loss: 0.0008, Val MSE Loss: 0.0008, Val Monotonicity Penalty: 0.0460, Val Violation Count: 2.00
# Epoch [22/100], Train Loss: 0.0003, Train MSE Loss: 0.0003, Train Monotonicity Penalty: 0.0166, Train Violation Count: 0.50, Val Loss: 0.0008, Val MSE Loss: 0.0008, Val Monotonicity Penalty: 0.0218, Val Violation Count: 1.67
# Epoch [23/100], Train Loss: 0.0019, Train MSE Loss: 0.0019, Train Monotonicity Penalty: 0.1446, Train Violation Count: 3.40, Val Loss: 0.0008, Val MSE Loss: 0.0008, Val Monotonicity Penalty: 0.0378, Val Violation Count: 2.00
# Epoch [24/100], Train Loss: 0.0004, Train MSE Loss: 0.0004, Train Monotonicity Penalty: 0.0660, Train Violation Count: 1.70, Val Loss: 0.0008, Val MSE Loss: 0.0008, Val Monotonicity Penalty: 0.0098, Val Violation Count: 1.33
# Epoch [25/100], Train Loss: 0.0004, Train MSE Loss: 0.0004, Train Monotonicity Penalty: 0.1051, Train Violation Count: 3.40, Val Loss: 0.0006, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0352, Val Violation Count: 1.67
# Epoch [26/100], Train Loss: 0.0004, Train MSE Loss: 0.0004, Train Monotonicity Penalty: 0.0669, Train Violation Count: 1.70, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [27/100], Train Loss: 0.0004, Train MSE Loss: 0.0004, Train Monotonicity Penalty: 0.0509, Train Violation Count: 2.00, Val Loss: 0.0006, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0589, Val Violation Count: 2.00
# Epoch [28/100], Train Loss: 0.0005, Train MSE Loss: 0.0005, Train Monotonicity Penalty: 0.0506, Train Violation Count: 1.30, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0088, Val Violation Count: 1.00
# Epoch [29/100], Train Loss: 0.0004, Train MSE Loss: 0.0004, Train Monotonicity Penalty: 0.0934, Train Violation Count: 2.00, Val Loss: 0.0008, Val MSE Loss: 0.0008, Val Monotonicity Penalty: 0.0161, Val Violation Count: 2.00
# Epoch [30/100], Train Loss: 0.0003, Train MSE Loss: 0.0003, Train Monotonicity Penalty: 0.0675, Train Violation Count: 2.20, Val Loss: 0.0007, Val MSE Loss: 0.0007, Val Monotonicity Penalty: 0.0347, Val Violation Count: 2.33
# Epoch [31/100], Train Loss: 0.0002, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0726, Train Violation Count: 2.40, Val Loss: 0.0007, Val MSE Loss: 0.0007, Val Monotonicity Penalty: 0.0088, Val Violation Count: 1.00
# Epoch [32/100], Train Loss: 0.0003, Train MSE Loss: 0.0003, Train Monotonicity Penalty: 0.1001, Train Violation Count: 2.90, Val Loss: 0.0006, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0221, Val Violation Count: 1.67
# Epoch [33/100], Train Loss: 0.0003, Train MSE Loss: 0.0003, Train Monotonicity Penalty: 0.0413, Train Violation Count: 2.10, Val Loss: 0.0005, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0303, Val Violation Count: 2.00
# Epoch [34/100], Train Loss: 0.0003, Train MSE Loss: 0.0003, Train Monotonicity Penalty: 0.0750, Train Violation Count: 2.20, Val Loss: 0.0007, Val MSE Loss: 0.0007, Val Monotonicity Penalty: 0.0153, Val Violation Count: 1.67
# Epoch [35/100], Train Loss: 0.0002, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0584, Train Violation Count: 1.70, Val Loss: 0.0006, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0170, Val Violation Count: 1.67
# Epoch [36/100], Train Loss: 0.0002, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0596, Train Violation Count: 1.30, Val Loss: 0.0007, Val MSE Loss: 0.0007, Val Monotonicity Penalty: 0.0041, Val Violation Count: 0.33
# Epoch [37/100], Train Loss: 0.0002, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.1162, Train Violation Count: 4.30, Val Loss: 0.0006, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0395, Val Violation Count: 2.00
# Epoch [38/100], Train Loss: 0.0002, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.1886, Train Violation Count: 5.40, Val Loss: 0.0006, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0073, Val Violation Count: 1.33
# Epoch [39/100], Train Loss: 0.0002, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0618, Train Violation Count: 2.50, Val Loss: 0.0006, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0036, Val Violation Count: 0.33
# Epoch [40/100], Train Loss: 0.0002, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.1538, Train Violation Count: 4.40, Val Loss: 0.0006, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0109, Val Violation Count: 1.33
# Epoch [41/100], Train Loss: 0.0002, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0575, Train Violation Count: 1.40, Val Loss: 0.0006, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0180, Val Violation Count: 2.00
# Epoch [42/100], Train Loss: 0.0002, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.1299, Train Violation Count: 5.40, Val Loss: 0.0007, Val MSE Loss: 0.0007, Val Monotonicity Penalty: 0.0077, Val Violation Count: 1.33
# Epoch [43/100], Train Loss: 0.0003, Train MSE Loss: 0.0003, Train Monotonicity Penalty: 0.0794, Train Violation Count: 2.40, Val Loss: 0.0004, Val MSE Loss: 0.0004, Val Monotonicity Penalty: 0.0189, Val Violation Count: 1.33
# Epoch [44/100], Train Loss: 0.0003, Train MSE Loss: 0.0003, Train Monotonicity Penalty: 0.0737, Train Violation Count: 2.60, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [45/100], Train Loss: 0.0002, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0694, Train Violation Count: 2.90, Val Loss: 0.0004, Val MSE Loss: 0.0004, Val Monotonicity Penalty: 0.1723, Val Violation Count: 5.00
# Epoch [46/100], Train Loss: 0.0004, Train MSE Loss: 0.0004, Train Monotonicity Penalty: 0.0600, Train Violation Count: 2.60, Val Loss: 0.0010, Val MSE Loss: 0.0010, Val Monotonicity Penalty: 0.0019, Val Violation Count: 0.33
# Epoch [47/100], Train Loss: 0.0002, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0463, Train Violation Count: 1.50, Val Loss: 0.0005, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0315, Val Violation Count: 2.00
# Epoch [48/100], Train Loss: 0.0002, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0496, Train Violation Count: 1.10, Val Loss: 0.0008, Val MSE Loss: 0.0008, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [49/100], Train Loss: 0.0002, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0695, Train Violation Count: 1.30, Val Loss: 0.0006, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0124, Val Violation Count: 1.33
# Epoch [50/100], Train Loss: 0.0002, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0567, Train Violation Count: 2.90, Val Loss: 0.0007, Val MSE Loss: 0.0007, Val Monotonicity Penalty: 0.0008, Val Violation Count: 0.33
# Epoch [51/100], Train Loss: 0.0001, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0675, Train Violation Count: 2.60, Val Loss: 0.0005, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0353, Val Violation Count: 2.00
# Epoch [52/100], Train Loss: 0.0001, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.1984, Train Violation Count: 4.50, Val Loss: 0.0008, Val MSE Loss: 0.0008, Val Monotonicity Penalty: 0.0023, Val Violation Count: 0.33
# Epoch [53/100], Train Loss: 0.0003, Train MSE Loss: 0.0003, Train Monotonicity Penalty: 0.1375, Train Violation Count: 4.30, Val Loss: 0.0004, Val MSE Loss: 0.0004, Val Monotonicity Penalty: 0.0403, Val Violation Count: 2.33
# Epoch [54/100], Train Loss: 0.0002, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.1428, Train Violation Count: 4.80, Val Loss: 0.0008, Val MSE Loss: 0.0008, Val Monotonicity Penalty: 0.0012, Val Violation Count: 0.33
# Epoch [55/100], Train Loss: 0.0002, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0514, Train Violation Count: 0.80, Val Loss: 0.0006, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0127, Val Violation Count: 1.33
# Epoch [56/100], Train Loss: 0.0001, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0415, Train Violation Count: 2.30, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0002, Val Violation Count: 0.33
# Epoch [57/100], Train Loss: 0.0002, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0188, Train Violation Count: 1.00, Val Loss: 0.0004, Val MSE Loss: 0.0004, Val Monotonicity Penalty: 0.0732, Val Violation Count: 3.67
# Epoch [58/100], Train Loss: 0.0002, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.1418, Train Violation Count: 4.90, Val Loss: 0.0009, Val MSE Loss: 0.0009, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [59/100], Train Loss: 0.0002, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0492, Train Violation Count: 1.00, Val Loss: 0.0005, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0441, Val Violation Count: 2.33
# Epoch [60/100], Train Loss: 0.0002, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.1068, Train Violation Count: 3.40, Val Loss: 0.0007, Val MSE Loss: 0.0007, Val Monotonicity Penalty: 0.0059, Val Violation Count: 0.33
# Epoch [61/100], Train Loss: 0.0001, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0796, Train Violation Count: 2.40, Val Loss: 0.0005, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0389, Val Violation Count: 2.67
# Epoch [62/100], Train Loss: 0.0002, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0609, Train Violation Count: 2.80, Val Loss: 0.0008, Val MSE Loss: 0.0008, Val Monotonicity Penalty: 0.0056, Val Violation Count: 0.33
# Epoch [63/100], Train Loss: 0.0002, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0901, Train Violation Count: 2.60, Val Loss: 0.0004, Val MSE Loss: 0.0004, Val Monotonicity Penalty: 0.0400, Val Violation Count: 2.33
# Epoch [64/100], Train Loss: 0.0002, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0613, Train Violation Count: 2.90, Val Loss: 0.0008, Val MSE Loss: 0.0008, Val Monotonicity Penalty: 0.0037, Val Violation Count: 0.33
# Epoch [65/100], Train Loss: 0.0001, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0330, Train Violation Count: 1.10, Val Loss: 0.0006, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0048, Val Violation Count: 0.33
# Epoch [66/100], Train Loss: 0.0002, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0261, Train Violation Count: 1.10, Val Loss: 0.0005, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0298, Val Violation Count: 2.00
# Epoch [67/100], Train Loss: 0.0002, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0941, Train Violation Count: 2.10, Val Loss: 0.0006, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0049, Val Violation Count: 0.33
# Epoch [68/100], Train Loss: 0.0001, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.1645, Train Violation Count: 7.20, Val Loss: 0.0006, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0390, Val Violation Count: 2.00
# Epoch [69/100], Train Loss: 0.0001, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0093, Train Violation Count: 0.80, Val Loss: 0.0005, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0127, Val Violation Count: 1.67
# Epoch [70/100], Train Loss: 0.0001, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0597, Train Violation Count: 2.50, Val Loss: 0.0006, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0088, Val Violation Count: 1.33
# Epoch [71/100], Train Loss: 0.0001, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0845, Train Violation Count: 4.30, Val Loss: 0.0006, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0181, Val Violation Count: 1.67
# Epoch [72/100], Train Loss: 0.0001, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0975, Train Violation Count: 2.00, Val Loss: 0.0005, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0391, Val Violation Count: 2.33
# Epoch [73/100], Train Loss: 0.0001, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0583, Train Violation Count: 2.40, Val Loss: 0.0005, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0100, Val Violation Count: 1.33
# Epoch [74/100], Train Loss: 0.0002, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0508, Train Violation Count: 1.30, Val Loss: 0.0007, Val MSE Loss: 0.0007, Val Monotonicity Penalty: 0.0027, Val Violation Count: 0.33
# Epoch [75/100], Train Loss: 0.0001, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0389, Train Violation Count: 1.60, Val Loss: 0.0005, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0030, Val Violation Count: 0.33
# Epoch [76/100], Train Loss: 0.0001, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0151, Train Violation Count: 1.00, Val Loss: 0.0007, Val MSE Loss: 0.0007, Val Monotonicity Penalty: 0.0057, Val Violation Count: 0.67
# Epoch [77/100], Train Loss: 0.0001, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0457, Train Violation Count: 2.10, Val Loss: 0.0006, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0052, Val Violation Count: 0.33
# Epoch [78/100], Train Loss: 0.0002, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.1484, Train Violation Count: 5.00, Val Loss: 0.0006, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0193, Val Violation Count: 2.33
# Epoch [79/100], Train Loss: 0.0001, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.1154, Train Violation Count: 4.00, Val Loss: 0.0006, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0104, Val Violation Count: 1.33
# Epoch [80/100], Train Loss: 0.0001, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0893, Train Violation Count: 2.10, Val Loss: 0.0006, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0056, Val Violation Count: 0.33
# Epoch [81/100], Train Loss: 0.0001, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0707, Train Violation Count: 2.40, Val Loss: 0.0005, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0113, Val Violation Count: 1.67
# Epoch [82/100], Train Loss: 0.0001, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0451, Train Violation Count: 2.00, Val Loss: 0.0005, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0108, Val Violation Count: 0.67
# Epoch [83/100], Train Loss: 0.0001, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.1770, Train Violation Count: 4.70, Val Loss: 0.0006, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0050, Val Violation Count: 0.67
# Epoch [84/100], Train Loss: 0.0001, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0476, Train Violation Count: 1.70, Val Loss: 0.0005, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0147, Val Violation Count: 1.33
# Epoch [85/100], Train Loss: 0.0001, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0891, Train Violation Count: 1.90, Val Loss: 0.0007, Val MSE Loss: 0.0007, Val Monotonicity Penalty: 0.0032, Val Violation Count: 0.33
# Epoch [86/100], Train Loss: 0.0001, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0713, Train Violation Count: 2.40, Val Loss: 0.0004, Val MSE Loss: 0.0004, Val Monotonicity Penalty: 0.0296, Val Violation Count: 2.33
# Epoch [87/100], Train Loss: 0.0001, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0716, Train Violation Count: 2.00, Val Loss: 0.0006, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0045, Val Violation Count: 0.33
# Epoch [88/100], Train Loss: 0.0001, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0217, Train Violation Count: 1.20, Val Loss: 0.0005, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0177, Val Violation Count: 1.33
# Epoch [89/100], Train Loss: 0.0001, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0266, Train Violation Count: 1.20, Val Loss: 0.0007, Val MSE Loss: 0.0007, Val Monotonicity Penalty: 0.0029, Val Violation Count: 0.33
# Epoch [90/100], Train Loss: 0.0001, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0900, Train Violation Count: 2.10, Val Loss: 0.0005, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0097, Val Violation Count: 0.67
# Epoch [91/100], Train Loss: 0.0005, Train MSE Loss: 0.0005, Train Monotonicity Penalty: 0.1660, Train Violation Count: 6.20, Val Loss: 0.0005, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0099, Val Violation Count: 0.67
# Epoch [92/100], Train Loss: 0.0001, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.1051, Train Violation Count: 5.30, Val Loss: 0.0006, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0062, Val Violation Count: 0.33
# Epoch [93/100], Train Loss: 0.0001, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0591, Train Violation Count: 1.60, Val Loss: 0.0007, Val MSE Loss: 0.0007, Val Monotonicity Penalty: 0.0005, Val Violation Count: 0.33
# Epoch [94/100], Train Loss: 0.0001, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0486, Train Violation Count: 1.80, Val Loss: 0.0006, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0163, Val Violation Count: 1.67
# Epoch [95/100], Train Loss: 0.0001, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0233, Train Violation Count: 2.00, Val Loss: 0.0006, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0101, Val Violation Count: 1.00
# Epoch [96/100], Train Loss: 0.0001, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0452, Train Violation Count: 1.90, Val Loss: 0.0006, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0233, Val Violation Count: 2.00
# Epoch [97/100], Train Loss: 0.0001, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.1292, Train Violation Count: 2.60, Val Loss: 0.0006, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [98/100], Train Loss: 0.0001, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0263, Train Violation Count: 1.00, Val Loss: 0.0006, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0079, Val Violation Count: 1.00
# Epoch [99/100], Train Loss: 0.0003, Train MSE Loss: 0.0003, Train Monotonicity Penalty: 0.0513, Train Violation Count: 2.00, Val Loss: 0.0005, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0126, Val Violation Count: 1.33
# Epoch [100/100], Train Loss: 0.0001, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0527, Train Violation Count: 1.50, Val Loss: 0.0006, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0039, Val Violation Count: 0.33
# lam = 0.0 - MAPE: 0.9263, MSE: 1855957760.0000, MAE: 20155.1230, RMSE: 43080.8281
# Training with lam = 0.2
# Epoch [1/100], Train Loss: 0.0070, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0055, Train Violation Count: 0.80, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [2/100], Train Loss: 0.0062, Train MSE Loss: 0.0062, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [3/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [4/100], Train Loss: 0.0069, Train MSE Loss: 0.0069, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [5/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [6/100], Train Loss: 0.0061, Train MSE Loss: 0.0061, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [7/100], Train Loss: 0.0062, Train MSE Loss: 0.0062, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [8/100], Train Loss: 0.0060, Train MSE Loss: 0.0060, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [9/100], Train Loss: 0.0061, Train MSE Loss: 0.0061, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [10/100], Train Loss: 0.0072, Train MSE Loss: 0.0072, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [11/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [12/100], Train Loss: 0.0061, Train MSE Loss: 0.0061, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [13/100], Train Loss: 0.0062, Train MSE Loss: 0.0062, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [14/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [15/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [16/100], Train Loss: 0.0062, Train MSE Loss: 0.0062, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [17/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [18/100], Train Loss: 0.0062, Train MSE Loss: 0.0062, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [19/100], Train Loss: 0.0061, Train MSE Loss: 0.0061, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [20/100], Train Loss: 0.0060, Train MSE Loss: 0.0060, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [21/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [22/100], Train Loss: 0.0061, Train MSE Loss: 0.0061, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [23/100], Train Loss: 0.0061, Train MSE Loss: 0.0061, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [24/100], Train Loss: 0.0069, Train MSE Loss: 0.0069, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [25/100], Train Loss: 0.0060, Train MSE Loss: 0.0060, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [26/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [27/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [28/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [29/100], Train Loss: 0.0060, Train MSE Loss: 0.0060, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [30/100], Train Loss: 0.0063, Train MSE Loss: 0.0063, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [31/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [32/100], Train Loss: 0.0063, Train MSE Loss: 0.0063, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [33/100], Train Loss: 0.0061, Train MSE Loss: 0.0061, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [34/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [35/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [36/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [37/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [38/100], Train Loss: 0.0062, Train MSE Loss: 0.0062, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [39/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [40/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [41/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [42/100], Train Loss: 0.0062, Train MSE Loss: 0.0062, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [43/100], Train Loss: 0.0060, Train MSE Loss: 0.0060, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [44/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [45/100], Train Loss: 0.0060, Train MSE Loss: 0.0060, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [46/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [47/100], Train Loss: 0.0060, Train MSE Loss: 0.0060, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [48/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [49/100], Train Loss: 0.0060, Train MSE Loss: 0.0060, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [50/100], Train Loss: 0.0061, Train MSE Loss: 0.0061, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [51/100], Train Loss: 0.0060, Train MSE Loss: 0.0060, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [52/100], Train Loss: 0.0061, Train MSE Loss: 0.0061, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [53/100], Train Loss: 0.0063, Train MSE Loss: 0.0063, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [54/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [55/100], Train Loss: 0.0061, Train MSE Loss: 0.0061, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [56/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [57/100], Train Loss: 0.0062, Train MSE Loss: 0.0062, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [58/100], Train Loss: 0.0063, Train MSE Loss: 0.0063, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [59/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [60/100], Train Loss: 0.0061, Train MSE Loss: 0.0061, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [61/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [62/100], Train Loss: 0.0068, Train MSE Loss: 0.0068, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [63/100], Train Loss: 0.0064, Train MSE Loss: 0.0064, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [64/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [65/100], Train Loss: 0.0060, Train MSE Loss: 0.0060, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [66/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [67/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [68/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [69/100], Train Loss: 0.0061, Train MSE Loss: 0.0061, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [70/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [71/100], Train Loss: 0.0060, Train MSE Loss: 0.0060, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [72/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [73/100], Train Loss: 0.0061, Train MSE Loss: 0.0061, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [74/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [75/100], Train Loss: 0.0060, Train MSE Loss: 0.0060, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [76/100], Train Loss: 0.0062, Train MSE Loss: 0.0062, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [77/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [78/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [79/100], Train Loss: 0.0068, Train MSE Loss: 0.0068, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [80/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [81/100], Train Loss: 0.0060, Train MSE Loss: 0.0060, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [82/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [83/100], Train Loss: 0.0063, Train MSE Loss: 0.0063, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [84/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [85/100], Train Loss: 0.0062, Train MSE Loss: 0.0062, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [86/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [87/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [88/100], Train Loss: 0.0060, Train MSE Loss: 0.0060, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [89/100], Train Loss: 0.0063, Train MSE Loss: 0.0063, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [90/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [91/100], Train Loss: 0.0064, Train MSE Loss: 0.0064, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [92/100], Train Loss: 0.0060, Train MSE Loss: 0.0060, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [93/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [94/100], Train Loss: 0.0061, Train MSE Loss: 0.0061, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [95/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [96/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [97/100], Train Loss: 0.0059, Train MSE Loss: 0.0059, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [98/100], Train Loss: 0.0062, Train MSE Loss: 0.0062, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [99/100], Train Loss: 0.0072, Train MSE Loss: 0.0072, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [100/100], Train Loss: 0.0060, Train MSE Loss: 0.0060, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0022, Val MSE Loss: 0.0022, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# lam = 0.2 - MAPE: 0.9644, MSE: 6363864576.0000, MAE: 39740.1562, RMSE: 79773.8359
# Training with lam = 0.5
# Epoch [1/100], Train Loss: 0.3827, Train MSE Loss: 0.0037, Train Monotonicity Penalty: 0.7580, Train Violation Count: 25.20, Val Loss: 0.0019, Val MSE Loss: 0.0019, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [2/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0018, Val MSE Loss: 0.0018, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [3/100], Train Loss: 0.0016, Train MSE Loss: 0.0016, Train Monotonicity Penalty: 0.0000, Train Violation Count: 0.00, Val Loss: 0.0018, Val MSE Loss: 0.0018, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [4/100], Train Loss: 0.0363, Train MSE Loss: 0.0012, Train Monotonicity Penalty: 0.0702, Train Violation Count: 1.40, Val Loss: 0.0141, Val MSE Loss: 0.0017, Val Monotonicity Penalty: 0.0249, Val Violation Count: 0.67
# Epoch [5/100], Train Loss: 0.0154, Train MSE Loss: 0.0014, Train Monotonicity Penalty: 0.0280, Train Violation Count: 0.50, Val Loss: 0.0144, Val MSE Loss: 0.0018, Val Monotonicity Penalty: 0.0252, Val Violation Count: 0.67
# Epoch [6/100], Train Loss: 0.0013, Train MSE Loss: 0.0012, Train Monotonicity Penalty: 0.0001, Train Violation Count: 0.10, Val Loss: 0.0136, Val MSE Loss: 0.0014, Val Monotonicity Penalty: 0.0243, Val Violation Count: 0.33
# Epoch [7/100], Train Loss: 0.0316, Train MSE Loss: 0.0015, Train Monotonicity Penalty: 0.0603, Train Violation Count: 1.10, Val Loss: 0.0152, Val MSE Loss: 0.0013, Val Monotonicity Penalty: 0.0278, Val Violation Count: 0.67
# Epoch [8/100], Train Loss: 0.0101, Train MSE Loss: 0.0010, Train Monotonicity Penalty: 0.0183, Train Violation Count: 0.50, Val Loss: 0.0099, Val MSE Loss: 0.0013, Val Monotonicity Penalty: 0.0173, Val Violation Count: 0.67
# Epoch [9/100], Train Loss: 0.0034, Train MSE Loss: 0.0010, Train Monotonicity Penalty: 0.0048, Train Violation Count: 0.30, Val Loss: 0.0077, Val MSE Loss: 0.0015, Val Monotonicity Penalty: 0.0123, Val Violation Count: 0.67
# Epoch [10/100], Train Loss: 0.0255, Train MSE Loss: 0.0012, Train Monotonicity Penalty: 0.0486, Train Violation Count: 0.40, Val Loss: 0.0020, Val MSE Loss: 0.0020, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [11/100], Train Loss: 0.0144, Train MSE Loss: 0.0008, Train Monotonicity Penalty: 0.0271, Train Violation Count: 0.50, Val Loss: 0.0151, Val MSE Loss: 0.0011, Val Monotonicity Penalty: 0.0281, Val Violation Count: 1.33
# ...
# Epoch [32/100], Train Loss: 0.1176, Train MSE Loss: 0.0004, Train Monotonicity Penalty: 0.1172, Train Violation Count: 3.10, Val Loss: 0.0657, Val MSE Loss: 0.0007, Val Monotonicity Penalty: 0.0650, Val Violation Count: 4.33
# Epoch [33/100], Train Loss: 0.0685, Train MSE Loss: 0.0003, Train Monotonicity Penalty: 0.0682, Train Violation Count: 1.90, Val Loss: 0.0407, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0401, Val Violation Count: 2.33
# Epoch [34/100], Train Loss: 0.0149, Train MSE Loss: 0.0003, Train Monotonicity Penalty: 0.0146, Train Violation Count: 0.60, Val Loss: 0.0366, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0360, Val Violation Count: 2.33
# Epoch [35/100], Train Loss: 0.0675, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0673, Train Violation Count: 2.70, Val Loss: 0.0864, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0859, Val Violation Count: 3.67
# Epoch [36/100], Train Loss: 0.0704, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0702, Train Violation Count: 2.90, Val Loss: 0.0370, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0364, Val Violation Count: 2.00
# Epoch [37/100], Train Loss: 0.0618, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0616, Train Violation Count: 2.00, Val Loss: 0.0528, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0523, Val Violation Count: 3.33
# Epoch [38/100], Train Loss: 0.0578, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0576, Train Violation Count: 2.20, Val Loss: 0.0491, Val MSE Loss: 0.0007, Val Monotonicity Penalty: 0.0484, Val Violation Count: 2.67
# Epoch [39/100], Train Loss: 0.0968, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0966, Train Violation Count: 3.60, Val Loss: 0.0203, Val MSE Loss: 0.0007, Val Monotonicity Penalty: 0.0196, Val Violation Count: 1.67
# Epoch [40/100], Train Loss: 0.1293, Train MSE Loss: 0.0007, Train Monotonicity Penalty: 0.1285, Train Violation Count: 2.60, Val Loss: 0.0810, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0805, Val Violation Count: 3.67
# Epoch [41/100], Train Loss: 0.0617, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0615, Train Violation Count: 2.70, Val Loss: 0.0310, Val MSE Loss: 0.0007, Val Monotonicity Penalty: 0.0304, Val Violation Count: 2.00
# Epoch [42/100], Train Loss: 0.0587, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0585, Train Violation Count: 1.50, Val Loss: 0.0723, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0718, Val Violation Count: 3.67
# Epoch [43/100], Train Loss: 0.0342, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0340, Train Violation Count: 1.70, Val Loss: 0.0361, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0355, Val Violation Count: 2.00
# Epoch [44/100], Train Loss: 0.0840, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0838, Train Violation Count: 2.60, Val Loss: 0.0729, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0724, Val Violation Count: 3.67
# Epoch [45/100], Train Loss: 0.0987, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0986, Train Violation Count: 3.30, Val Loss: 0.0212, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0206, Val Violation Count: 1.67
# Epoch [46/100], Train Loss: 0.1444, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.1442, Train Violation Count: 4.80, Val Loss: 0.0401, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0396, Val Violation Count: 2.33
# Epoch [47/100], Train Loss: 0.1039, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.1037, Train Violation Count: 1.60, Val Loss: 0.0476, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0471, Val Violation Count: 2.67
# Epoch [48/100], Train Loss: 0.0555, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0553, Train Violation Count: 2.70, Val Loss: 0.0311, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0306, Val Violation Count: 2.00
# Epoch [49/100], Train Loss: 0.0293, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0291, Train Violation Count: 1.30, Val Loss: 0.0134, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0128, Val Violation Count: 1.33
# Epoch [50/100], Train Loss: 0.0454, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0452, Train Violation Count: 1.80, Val Loss: 0.0589, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0584, Val Violation Count: 3.00
# Epoch [51/100], Train Loss: 0.0362, Train MSE Loss: 0.0004, Train Monotonicity Penalty: 0.0357, Train Violation Count: 1.60, Val Loss: 0.0217, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0211, Val Violation Count: 1.67
# Epoch [52/100], Train Loss: 0.0492, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0491, Train Violation Count: 1.80, Val Loss: 0.0417, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0412, Val Violation Count: 2.00
# Epoch [53/100], Train Loss: 0.0529, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0528, Train Violation Count: 3.00, Val Loss: 0.0117, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0111, Val Violation Count: 1.33
# Epoch [54/100], Train Loss: 0.0399, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0398, Train Violation Count: 1.90, Val Loss: 0.0509, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0504, Val Violation Count: 2.33
# Epoch [55/100], Train Loss: 0.0989, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0987, Train Violation Count: 2.10, Val Loss: 0.0207, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0202, Val Violation Count: 2.00
# Epoch [56/100], Train Loss: 0.1234, Train MSE Loss: 0.0003, Train Monotonicity Penalty: 0.1231, Train Violation Count: 3.70, Val Loss: 0.0077, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0071, Val Violation Count: 1.33
# Epoch [57/100], Train Loss: 0.1815, Train MSE Loss: 0.0006, Train Monotonicity Penalty: 0.1809, Train Violation Count: 5.80, Val Loss: 0.0540, Val MSE Loss: 0.0004, Val Monotonicity Penalty: 0.0535, Val Violation Count: 2.33
# Epoch [58/100], Train Loss: 0.1221, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.1219, Train Violation Count: 4.10, Val Loss: 0.0142, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0137, Val Violation Count: 1.33
# Epoch [59/100], Train Loss: 0.0298, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0296, Train Violation Count: 1.60, Val Loss: 0.0364, Val MSE Loss: 0.0004, Val Monotonicity Penalty: 0.0359, Val Violation Count: 2.00
# Epoch [60/100], Train Loss: 0.0527, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0525, Train Violation Count: 2.10, Val Loss: 0.0351, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0345, Val Violation Count: 1.67
# Epoch [61/100], Train Loss: 0.0265, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0263, Train Violation Count: 1.80, Val Loss: 0.0601, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0596, Val Violation Count: 3.67
# Epoch [62/100], Train Loss: 0.1376, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.1373, Train Violation Count: 4.10, Val Loss: 0.0499, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0494, Val Violation Count: 2.67
# Epoch [63/100], Train Loss: 0.0375, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0373, Train Violation Count: 1.50, Val Loss: 0.0008, Val MSE Loss: 0.0008, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [64/100], Train Loss: 0.0614, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0612, Train Violation Count: 1.60, Val Loss: 0.1163, Val MSE Loss: 0.0004, Val Monotonicity Penalty: 0.1159, Val Violation Count: 4.33
# Epoch [65/100], Train Loss: 0.0343, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0342, Train Violation Count: 1.10, Val Loss: 0.0209, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0203, Val Violation Count: 2.00
# Epoch [66/100], Train Loss: 0.0891, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0889, Train Violation Count: 3.50, Val Loss: 0.0439, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0432, Val Violation Count: 2.00
# Epoch [67/100], Train Loss: 0.0303, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0301, Train Violation Count: 1.60, Val Loss: 0.0272, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0266, Val Violation Count: 2.00
# Epoch [68/100], Train Loss: 0.0572, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0570, Train Violation Count: 0.30, Val Loss: 0.0131, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0125, Val Violation Count: 1.33
# Epoch [69/100], Train Loss: 0.0175, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0173, Train Violation Count: 1.20, Val Loss: 0.2426, Val MSE Loss: 0.0004, Val Monotonicity Penalty: 0.2422, Val Violation Count: 7.00
# Epoch [70/100], Train Loss: 0.0682, Train MSE Loss: 0.0004, Train Monotonicity Penalty: 0.0678, Train Violation Count: 3.90, Val Loss: 0.0248, Val MSE Loss: 0.0008, Val Monotonicity Penalty: 0.0241, Val Violation Count: 2.00
# Epoch [71/100], Train Loss: 0.0630, Train MSE Loss: 0.0003, Train Monotonicity Penalty: 0.0627, Train Violation Count: 2.40, Val Loss: 0.0401, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0396, Val Violation Count: 2.00
# Epoch [72/100], Train Loss: 0.0443, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0442, Train Violation Count: 1.30, Val Loss: 0.1925, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.1920, Val Violation Count: 6.00
# Epoch [73/100], Train Loss: 0.1393, Train MSE Loss: 0.0003, Train Monotonicity Penalty: 0.1390, Train Violation Count: 4.00, Val Loss: 0.0061, Val MSE Loss: 0.0007, Val Monotonicity Penalty: 0.0054, Val Violation Count: 0.67
# Epoch [74/100], Train Loss: 0.0273, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0270, Train Violation Count: 1.60, Val Loss: 0.1423, Val MSE Loss: 0.0004, Val Monotonicity Penalty: 0.1419, Val Violation Count: 4.67
# Epoch [75/100], Train Loss: 0.0784, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0781, Train Violation Count: 2.00, Val Loss: 0.0006, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0000, Val Violation Count: 0.00
# Epoch [76/100], Train Loss: 0.0194, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0192, Train Violation Count: 0.90, Val Loss: 0.0726, Val MSE Loss: 0.0004, Val Monotonicity Penalty: 0.0722, Val Violation Count: 3.67
# Epoch [77/100], Train Loss: 0.0716, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0714, Train Violation Count: 2.20, Val Loss: 0.0184, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0179, Val Violation Count: 1.67
# Epoch [78/100], Train Loss: 0.0509, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0508, Train Violation Count: 0.60, Val Loss: 0.0359, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0354, Val Violation Count: 2.00
# Epoch [79/100], Train Loss: 0.0514, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0512, Train Violation Count: 2.00, Val Loss: 0.0336, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0331, Val Violation Count: 2.00
# Epoch [80/100], Train Loss: 0.0655, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0654, Train Violation Count: 2.00, Val Loss: 0.0263, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0259, Val Violation Count: 1.67
# Epoch [81/100], Train Loss: 0.0496, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0495, Train Violation Count: 2.00, Val Loss: 0.0110, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0104, Val Violation Count: 1.33
# Epoch [82/100], Train Loss: 0.0536, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0535, Train Violation Count: 1.40, Val Loss: 0.0487, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0482, Val Violation Count: 2.33
# Epoch [83/100], Train Loss: 0.0623, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0622, Train Violation Count: 2.70, Val Loss: 0.0613, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0608, Val Violation Count: 3.00
# Epoch [84/100], Train Loss: 0.1793, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.1792, Train Violation Count: 4.30, Val Loss: 0.0160, Val MSE Loss: 0.0007, Val Monotonicity Penalty: 0.0154, Val Violation Count: 1.33
# Epoch [85/100], Train Loss: 0.1841, Train MSE Loss: 0.0011, Train Monotonicity Penalty: 0.1830, Train Violation Count: 6.80, Val Loss: 0.0239, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0234, Val Violation Count: 1.67
# Epoch [86/100], Train Loss: 0.0920, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0919, Train Violation Count: 1.90, Val Loss: 0.0630, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0625, Val Violation Count: 3.33
# Epoch [87/100], Train Loss: 0.0981, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0979, Train Violation Count: 2.60, Val Loss: 0.0133, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0127, Val Violation Count: 1.67
# Epoch [88/100], Train Loss: 0.1350, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.1348, Train Violation Count: 4.60, Val Loss: 0.0746, Val MSE Loss: 0.0004, Val Monotonicity Penalty: 0.0742, Val Violation Count: 4.00
# Epoch [89/100], Train Loss: 0.0471, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0470, Train Violation Count: 2.60, Val Loss: 0.0404, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0399, Val Violation Count: 2.00
# Epoch [90/100], Train Loss: 0.0429, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0428, Train Violation Count: 1.90, Val Loss: 0.0588, Val MSE Loss: 0.0004, Val Monotonicity Penalty: 0.0584, Val Violation Count: 3.00
# Epoch [91/100], Train Loss: 0.0314, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0313, Train Violation Count: 0.90, Val Loss: 0.0609, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0604, Val Violation Count: 3.33
# Epoch [92/100], Train Loss: 0.0520, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0519, Train Violation Count: 3.10, Val Loss: 0.0687, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0682, Val Violation Count: 3.33
# Epoch [93/100], Train Loss: 0.0460, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0460, Train Violation Count: 1.90, Val Loss: 0.0489, Val MSE Loss: 0.0004, Val Monotonicity Penalty: 0.0485, Val Violation Count: 2.67
# Epoch [94/100], Train Loss: 0.0518, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0517, Train Violation Count: 1.20, Val Loss: 0.0234, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0228, Val Violation Count: 1.67
# Epoch [95/100], Train Loss: 0.0373, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0372, Train Violation Count: 1.40, Val Loss: 0.0861, Val MSE Loss: 0.0004, Val Monotonicity Penalty: 0.0857, Val Violation Count: 4.67
# Epoch [96/100], Train Loss: 0.1676, Train MSE Loss: 0.0006, Train Monotonicity Penalty: 0.1669, Train Violation Count: 5.40, Val Loss: 0.0321, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0316, Val Violation Count: 2.00
# Epoch [97/100], Train Loss: 0.0665, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0664, Train Violation Count: 2.50, Val Loss: 0.1498, Val MSE Loss: 0.0004, Val Monotonicity Penalty: 0.1495, Val Violation Count: 5.33
# Epoch [98/100], Train Loss: 0.1883, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.1881, Train Violation Count: 6.80, Val Loss: 0.0119, Val MSE Loss: 0.0006, Val Monotonicity Penalty: 0.0113, Val Violation Count: 1.00
# Epoch [99/100], Train Loss: 0.0884, Train MSE Loss: 0.0002, Train Monotonicity Penalty: 0.0882, Train Violation Count: 4.70, Val Loss: 0.0607, Val MSE Loss: 0.0004, Val Monotonicity Penalty: 0.0602, Val Violation Count: 3.00
# Epoch [100/100], Train Loss: 0.0945, Train MSE Loss: 0.0001, Train Monotonicity Penalty: 0.0944, Train Violation Count: 2.50, Val Loss: 0.0512, Val MSE Loss: 0.0005, Val Monotonicity Penalty: 0.0507, Val Violation Count: 2.67
# lam = 1.0 - MAPE: 0.7376, MSE: 1320856704.0000, MAE: 18738.0605, RMSE: 36343.5938
# Best lam: 1.0
# Best Model - MAPE: 0.7376, MSE: 1320856704.0000, MAE: 18738.0605, RMSE: 36343.5938
# Average Train Violation Count: 2.10
# Average Test Violation Count: 2.22
